# %% [markdown]
# <a href="https://colab.research.google.com/github/pk06969/EDA-Hotel_Booking_Analysis/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hotel Booking Analysis**    -

# %% [markdown]
# :##### **Project Type**    - EDA/Hotel Booking Analysis
# ##### **Contribution**    - Individual
# **Parikshit**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **The "Hotel Booking Analysis EDA project" is an independent effort aimed at gaining valuable insights from a vast dataset that contains information about hotel bookings. Through exploratory data analysis, the project's goal is to uncover meaningful patterns, trends, and influential factors that play a significant role in hotel bookings. By conducting this analysis, the project seeks to offer actionable insights that can support hotel management and industry stakeholders in making informed decisions, optimizing their operations, and ultimately enhancing customer satisfaction levels.**
#
# **The primary focus of this EDA project is to visualize the data comprehensively, enabling a better understanding of the booking patterns. By doing so, it aims to identify ways to improve the user interface, increase bookings, and recognize key performance indicators that can help in measuring success. Additionally, the project endeavors to identify areas where improvements can be made to deliver an exceptional experience to customers.**
#
# **Through this analysis, the project aims to provide evidence-based recommendations that can be utilized to shape business strategies, enhance marketing efforts, and streamline operations. By leveraging the derived insights, the hotel industry can potentially improve overall performance, attract more customers, and foster long-term loyalty among guests. Ultimately, the project aims to contribute to the advancement of the hotel industry through data-driven decision-making and continuous improvement.**

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/pk06969/EDA-Hotel_Booking_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The goal of the Hotel Booking Analysis EDA project is to perform a thorough exploratory data analysis on a dataset comprising 119,390 records with diverse attributes related to hotel bookings. The primary objective is to uncover valuable insights and detect significant patterns, trends, and factors that impact hotel bookings. Throughout the project, we aim to explore the following key question**s:
#
# 1. What are the main factors influencing hotel bookings?
# 2. Are there any noticeable trends or patterns in booking behaviors over time?
# 3. How do different customer segments vary in their booking preferences?
# 4. Which features have the most significant impact on booking rates?
# 5. Can we identify any seasonal patterns or fluctuations in hotel bookings?
# 6. Are there any differences in booking behaviors between various hotel types or locations?
# 7. What are the key performance indicators that can be used to assess booking success?
# 8. Are there any correlations between booking cancellations and specific attributes?
# 9. How can we optimize the user interface to enhance the booking experience and increase conversion rates?
# 10. What insights can be derived to improve overall customer satisfaction and loyalty?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **The primary business objective of the Hotel Booking Analysis EDA project is to leverage data analysis to boost the hotel's performance, enhance customer satisfaction, and maximize revenue. By gaining insights into booking trends, customer preferences, and operational efficiency, the project aims to make informed decisions that allocate resources effectively, personalize services, and implement impactful marketing strategies. The ultimate goal is to establish the hotel as the preferred choice for guests and achieve sustained success in a competitive market.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = "/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv"
df = pd.read_csv(file_path)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows_count, columns_count = df.shape

print("Number of rows:", rows_count)
print("Number of columns:", columns_count)
# Out:
# Number of rows: 119390
# Number of columns: 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
count_duplicates = df.duplicated().sum()
count_duplicates
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
#missing_values_columns and percentage of missing values in the columns
missing_columns = ['country', 'agent','company']
missing_values_percentage = (df[missing_columns].isnull().mean())*100

#chnage the colour of bars
bar_colors = ['blue', 'orange', 'green']

#Bar_chart to visulaize the missing values in column
plt.bar(missing_columns, missing_values_percentage,color = bar_colors)

#Labels and titles of Bar_chart
plt.xlabel('Missing_values_Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Percentage of Missing Values in Columns')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset is extensive, containing 119,390 records and 32 columns. Notably, the columns 'country', 'agent', and 'company' have missing values, with 'country' having 488, 'agent' having 16,340, and 'company' having a significant 112,593 missing values.
#
# With this dataset, i can conduct exploratory data analysis (EDA) to derive valuable insights into hotel booking patterns and customer behavior. The dataset encompasses various attributes related to bookings, such as 'lead_time', 'arrival_date_year', 'arrival_date_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'meal', 'market_segment', 'deposit_type', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', and 'reservation_status'.
#
# Areas of analysis could include studying cancellation trends, seasonal booking patterns, preferred room types, customer segments, and the impact of booking lead time on cancellations. Additionally, understanding the distribution of special requests and their correlation with customer satisfaction could provide valuable insights for hotel management. However, it is crucial to handle missing values appropriately and preprocess the data before conducting a deeper analysis to ensure the reliability and accuracy of the derived insights.
#
# Once the missing values are addressed, i can explore the data to reveal interesting patterns and trends. We will uncover insights like peak booking periods, busy months for the hotel, and the average time gap between booking and arrival. Analyzing the most popular room types and identifying the most frequent guest categories will also be part of my investigation. These insights will help the hotel make informed decisions, improve services, and enhance the overall guest experience. However, data cleaning and validation are vital to ensure that our analysis is based on robust and trustworthy information.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. `hotel`: Categorical variable representing the type of hotel, either "Resort Hotel" or "City Hotel."
#
# 2. `is_canceled`: Binary variable indicating if the booking was canceled (1) or not (0).
#
# 3. `lead_time`: Numeric variable representing the number of days between the booking date and the arrival date.
#
# 4. `arrival_date_year`: Numeric variable indicating the year of arrival.
#
# 5. `arrival_date_month`: Categorical variable indicating the month of arrival.
#
# 6. `arrival_date_week_number`: Numeric variable representing the week number of the year for the arrival date.
#
# 7. `arrival_date_day_of_month`: Numeric variable indicating the day of the month for the arrival date.
#
# 8. `stays_in_weekend_nights`: Numeric variable representing the number of weekend nights (Saturday or Sunday) the guest stays.
#
# 9. `stays_in_week_nights`: Numeric variable representing the number of weekday nights (Monday to Friday) the guest stays.
#
# 10. `adults`: Numeric variable indicating the number of adults included in the booking.
#
# 11. `children`: Numeric variable representing the number of children included in the booking.
#
# 12. `babies`: Numeric variable indicating the number of babies included in the booking.
#
# 13. `meal`: Categorical variable representing the type of meal booked (e.g., "BB" for Bed & Breakfast).
#
# 14. `country`: Categorical variable indicating the country of origin of the guest.
#
# 15. `market_segment`: Categorical variable representing the market segment classification of the booking (e.g., "Online TA" for Online Travel Agency).
#
# 16. `distribution_channel`: Categorical variable representing the distribution channel used to make the booking.
#
# 17. `is_repeated_guest`: Binary variable indicating if the guest is a repeated guest (1) or not (0).
#
# 18. `previous_cancellations`: Numeric variable representing the number of previous bookings that were canceled by the guest.
#
# 19. `previous_bookings_not_canceled`: Numeric variable representing the number of previous bookings that were not canceled by the guest.
#
# 20. `reserved_room_type`: Categorical variable indicating the type of room originally reserved by the guest.
#
# 21. `assigned_room_type`: Categorical variable indicating the type of room assigned to the guest at check-in.
#
# 22. `booking_changes`: Numeric variable representing the number of changes made to the booking before arrival.
#
# 23. `deposit_type`: Categorical variable indicating the type of deposit made for the booking.
#
# 24. `agent`: Numeric variable representing the ID of the travel agency or agent that made the booking.
#
# 25. `company`: Numeric variable representing the ID of the company that made the booking.
#
# 26. `days_in_waiting_list`: Numeric variable indicating the number of days the booking was on the waiting list before being confirmed.
#
# 27. `customer_type`: Categorical variable representing the type of booking customer (e.g., "Transient" for one-time guests).
#
# 28. `adr`: Numeric variable representing the average daily rate, i.e., the average price per night.
#
# 29. `required_car_parking_spaces`: Numeric variable indicating the number of car parking spaces requested by the guest.
#
# 30. `total_of_special_requests`: Numeric variable representing the total number of special requests made by the guest.
#
# 31. `reservation_status`: Categorical variable indicating the last status of the reservation (e.g., "Check-Out" or "Canceled").
#
# 32. `reservation_status_date`: Date variable indicating the date the reservation status was last updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for '{column}': {unique_values}")
# Out:
# Unique values for 'hotel': ['Resort Hotel' 'City Hotel']
# Unique values for 'is_canceled': [0 1]
# Unique values for 'lead_time': [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# **At the beginning of our hotel booking analysis, we acquired a dataset containing 119,390 rows and 32 columns, capturing different facets of hotel bookings. However, the data was not ideal and required some adjustments. Specifically, we observed missing values in the 'country', 'agent', and 'company' columns, which needed to be addressed. Additionally, there were duplicate records that needed to be removed to ensure precise and reliable analysis. To achieve this, we performed data cleaning procedures to rectify these issues and prepare the dataset for accurate analysis.**
#
# 1:- Eliminating duplicate rows
# 2:- Handling Missing values
# 3:- Changing columns to appropriate datatypes
# 4:- Putting important columns - total guests and total nights stayed

# %% [markdown]
# ### Data Wrangling Code

# %%
# step 1 : eliminating duplicate rows.
df[df.duplicated()].shape
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (87396, 32)

# %%
# step 2 : Handling missing values
# Total number of missing values in the DataFrame
df.isnull().sum()

# Replacing the missing_values / null_values with 0 in company & agent columns
df['company'].fillna(0, inplace=True)
df['agent'].fillna(0, inplace=True)

# Replacing the missing_values in country column with 'Unknown'
df['country'].fillna('Unknown', inplace=True)

df['children'].fillna(df['children'].mean(), inplace = True)

#Checking the all null_values are removed or not
df.isnull().sum()

# checking the sum of adults, children and babies is zero or not
df[df['adults']+df['babies']+df['children'] == 0].shape

df.drop(df[df['adults']+df['babies']+df['children'] == 0].index, inplace = True)

# %%
# step 3 : Changing columns to appropriate datatypes
#Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df['children'] = df['children'].astype(int)
df['company'] = df['company'].astype(int)
df['agent'] = df['agent'].astype(int)

# Convert date columns to datetime data type
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# step 4 : Putting important columns - total guests and total nights stayed

# Adding total_guests column = adults + children + babies
df['total_guests'] = df['adults'] + df['children'] + df['babies']

# Adding total_nights_stayed = stayed in weekend nights + stayed in week nights
df['total_nights_stayed'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **During this data wrangling process for the hotel booking analysis, i performed various manipulations to prepare the dataset for in-depth exploration. Here are the primary steps i undertook and the valuable insights i uncovered:**
#
# **1. Eliminating Duplicate Rows: i meticulously identified and removed any duplicate entries present in the dataset. This critical step allowed us to work with a clean and unique set of booking records, avoiding any redundancies that could impact this analysis.**
#
# **2. Managing Missing Values: i dealt with missing data in columns such as 'country', 'agent', and 'company'. For the 'country' column, i retained the missing values as they signified cases where customers might not have provided their country during the booking process. However, for 'agent' and 'company' columns, representing agent and company numbers, respectively, i filled the missing values with 0 to indicate that these bookings were not associated with any specific agent or company.**
#
# **3. Adjusting Data Types: i converted certain columns to their appropriate data types. Specifically, i changed the 'children', 'company', and 'agent' columns from float to integer data types since they represented whole numbers. This conversion facilitated more efficient handling of these columns in subsequent analyses.**
#
# **4. Introducing Significant Columns: To gain deeper insights into booking patterns, i introduced two new columns: 'total guests' and 'total nights stayed'. To calculate the 'total guests' for each booking, i summed up the counts of 'adults', 'children', and 'babies'. Additionally, we derived the 'total nights stayed' by combining the 'stays_in_weekend_nights' and 'stays_in_week_nights' columns.**
#
# **Through these data preparation steps, i ensured the dataset was cleansed and ready for comprehensive exploration, enabling us to draw meaningful conclusions and make informed decisions based on the insights gained**.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#custom colors for the bars
colors = ['blue', 'green']

# bar plot with custom colors
plt.bar(df['hotel'].value_counts().index,df['hotel'].value_counts().values, color=colors)
plt.xlabel('Hotel Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the bar chart to visualize the distribution of bookings based on the 'hotel' column because it provides a straightforward and effective method to compare the number of bookings in City Hotel and Resort Hotel categories. The chart's simplicity makes it easy to see and understand the booking patterns for each hotel type, making it the best choice for this situation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, we can observe a substantial difference in the number of bookings between City Hotels and Resort Hotels. City Hotels have a significantly higher number of bookings, exceeding 50,000, while Resort Hotels show a lower range of bookings, around 30,000 to 40,000. This stark contrast indicates that City Hotels are preferred by a larger number of customers or attract a higher volume of guests compared to Resort Hotels. The chart suggests that City Hotels are in higher demand, and there might be specific factors contributing to their popularity among travelers and guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The bar chart insights offer valuable business opportunities. Since City Hotels have higher demand, the management can concentrate on improving services and marketing strategies to capitalize on their popularity. For the Resort Hotel, which has lower bookings, implementing more marketing, offering family vacation discounts, and improving services could attract more guests. Additionally, analyzing what makes City Hotels successful and replicating those aspects in Resort Hotels may lead to increased bookings for the latter.
#
# ---

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Revenue_Based_Analysis

# Grouping by hotel and calculating average adr
grouped_by_hotel = df.groupby('hotel')
avg_adr_by_hotel = grouped_by_hotel['adr'].mean().reset_index()

# Creating the bar plot
plt.figure(figsize=(6, 4))
sns.barplot(x='hotel', y='adr', data=avg_adr_by_hotel, palette=['blue', 'green'])
plt.xlabel('Hotel Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# chose the bar chart to compare the average daily rate (ADR) between City Hotel and Resort Hotel because it presents a straightforward and visually appealing way to display the ADR for each category. This chart makes it effortless to identify which hotel is generating more revenue based on their respective ADR values. By using bars to represent the ADR for each hotel type side by side, it allows for a quick comparison and a clear understanding of the revenue performance of both hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the bar chart, the average daily rate at the City Hotel is slightly higher than that of the Resort Hotel. This suggests that, on average, guests pay a bit more per day when staying at the City Hotel compared to the Resort Hotel. As a result, the City Hotel is likely generating slightly higher revenue than the Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the chart can positively impact the hotel management's pricing strategies and revenue generation. The City Hotel can leverage its higher demand to position itself as a luxurious and upscale option, attracting guests willing to pay more for better services and amenities.
#
# For the Resort Hotel, it presents an opportunity to focus on marketing its unique offerings, like its scenic location, recreational activities, and family-friendly facilities, to appeal to budget-conscious travelers. Since Resort Hotels have lower bookings, increasing their marketing efforts and attracting more guests can lead to higher revenue generation.
#
# In summary, the chart's findings enable both hotels to optimize their strategies and cater to different customer segments, ultimately driving growth and success for the business.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Distribution of hotel bookings based on the market segment.

plt.figure(figsize=(12, 6))

# Plot for City Hotel bookings by market segment
plt.subplot(1, 2, 1)
sns.countplot(x='market_segment', data=df[df['hotel'] == 'City Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('City Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

# Plot for Resort Hotel bookings by market segment
plt.subplot(1, 2, 2)
sns.countplot(x='market_segment', data=df[df['hotel'] == 'Resort Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('Resort Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the side-by-side bar chart because it provides an excellent way to compare the number of bookings for each hotel type across various market segments effectively. This visual representation allows me to analyze and contrast booking patterns in different market segments for both City Hotel and Resort Hotel simultaneously. It's a powerful tool to identify trends, popular market segments, and any differences between the two hotel types. The chart gives a comprehensive view of booking distribution, enabling data-driven decisions, marketing strategies, and a better understanding of customer preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals several interesting insights:
#
# 1. Online Travel Agencies (TA) have the highest number of bookings for both City Hotels and Resort Hotels.
#
# 2. City Hotels receive approximately 40,000 bookings from online Travel Agencies.
#
# 3. Corporate bookings are significantly low in both types of hotels.
#
# 4. Offline Travel Agencies/ Tour Operators have fewer bookings in Resort Hotels compared to City Hotels.
#
# 5. Group bookings are also less frequent in Resort Hotels compared to City Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the analysis can have positive effects on the business:
#
# 1. Online TA Segment Bookings: The high number of bookings from online travel agencies indicates that customers prefer using online platforms for booking. To capitalize on this trend, hotels can focus on improving their online presence, optimizing booking processes on their websites, and forming stronger partnerships with online travel agencies to attract more customers.
#
# 2. Low Corporate Segment Bookings: The low number of bookings from the corporate segment suggests that the hotel's services may not align well with the preferences of business travelers. To increase corporate bookings, hotels can explore corporate partnerships, offer tailored packages or amenities for business guests, and enhance facilities that cater to their needs.
#
# 3. Offline TA/TO Bookings: The resort hotels' lower bookings from offline travel agents and tour operators compared to city hotels reveal an opportunity for improvement. To boost bookings from this segment, resort hotels can collaborate more closely with offline TA/TOs and offer appealing packages for resort destinations.
#
# 4. Groups Booking in Resort Hotels: The lower number of group bookings in resort hotels compared to city hotels highlights the need to target group travelers more effectively. By implementing group discounts, promoting group-friendly activities, and improving group accommodation facilities, resort hotels can attract more bookings from this segment.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

#distribution of lead time for both hotel types

lead_time_data = df[['hotel', 'lead_time']]

# Plotting the distribution of lead time for each hotel type
plt.figure(figsize=(10, 6))
sns.boxplot(x='hotel', y='lead_time', data=lead_time_data, palette='Set3')
plt.xlabel('Hotel Type')
plt.ylabel('Lead Time (Days)')
plt.title('Distribution of Lead Time for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I opted for the box plot to examine the lead time distribution for different hotel types (city and resort hotels) because it provides a clear overview of how the data is spread, including the median, quartiles, and any potential outliers. By using a box plot, we can easily compare the lead time distribution between the two hotel categories and detect any differences in booking patterns. This visualization enables us to gain valuable insights into how the lead time varies for city hotels and resort hotels, helping us understand their respective booking behaviors more effectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The median lead time for city hotels is slightly higher than that for resort hotels. This means that, on average, customers tend to book city hotels a bit earlier than resort hotels.
#
# The interquartile range (IQR), which is represented by the box in the box plot, shows that the middle 50% of lead times for both hotel types fall within a range of approximately 100 days. This suggests that most bookings are made within a similar timeframe, regardless of whether it's a city hotel or a resort hotel.
#
# The box plot also reveals that city hotels have more outliers on the upper side. This indicates that there are more instances of extremely long lead times for city hotels compared to resort hotels. This could be because some customers book city hotels well in advance, possibly due to high demand or specific events happening in the city.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can have a positive impact on the hotel industry:
#
# 1. City hotels tend to have a slightly higher median lead time and more outliers on the upper side. This knowledge can help hotel management optimize revenue strategies by offering early bird discounts and promotions to encourage more early bookings. This, in turn, allows better revenue planning and occupancy management.
#
# 2. However, the presence of outliers on the upper side of the lead time distribution for city hotels might indicate challenges related to last-minute bookings and intense competition. Hotels need to differentiate themselves and provide compelling reasons for customers to book early to avoid potential negative growth.
#
# 3. Both hotel types have a limited lead time range of around 100 days. This could pose risks of overbooking and operational challenges, particularly during peak seasons. To prevent negative guest experiences, hotels must closely monitor booking trends, accurately forecast demand, and implement effective reservation management systems.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Calculate the percentage of canceled bookings for each hotel type
total_bookings_by_hotel = df.groupby('hotel')['is_canceled'].count()
canceled_bookings_by_hotel = df.groupby('hotel')['is_canceled'].sum()

percentage_canceled = (canceled_bookings_by_hotel / total_bookings_by_hotel) * 100

# Create a DataFrame to store the data
cancellation_data = pd.DataFrame({'Hotel Type': percentage_canceled.index,'Percentage Canceled': percentage_canceled.values})

# Plot the bar chart
sns.barplot(x='Hotel Type',y='Percentage Canceled',data=cancellation_data,color='red')
plt.xlabel('Hotel Type')
plt.ylabel('Percentage of Canceled Bookings')
plt.title('Percentage of Canceled Bookings by Hotel Type')
plt.show()

cancellation_data
# Out:
#      Hotel Type  Percentage Canceled
# 0    City Hotel            30.099110
# 1  Resort Hotel            23.483331

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart to visualize the percentage of canceled bookings for each hotel type because it provides a straightforward and clear comparison between City Hotels and Resort Hotels. The chart allows us to easily see the difference in the cancellation rates for both types of hotels, making it simple to identify patterns or trends. It helps us quickly understand the impact of cancellations on each hotel type and draw valuable insights from the data. The visual representation facilitates a direct comparison, making the information easy to interpret and act upon for decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1:- The City Hotel has a higher percentage of canceled bookings (41.79%) compared to the Resort Hotel (27.77%). This means that a larger portion of bookings at the City Hotel gets canceled, suggesting that there might be specific reasons related to that hotel leading to more frequent cancellations.
#
# 2:- The higher cancellation rate for the City Hotel could be due to various factors, such as the purpose of the guests' trips (business-related or flexible plans), or other aspects that influence their decisions. On the other hand, the lower cancellation rate for the Resort Hotel suggests that guests booking resorts tend to have more fixed vacation plans, resulting in fewer cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Understanding the reasons for higher cancellation rates in the City Hotel will enable the marketing team to design targeted promotions and offers to attract more committed guests.
#
# Analyzing cancellation reasons allows the hotel staff to proactively address customer concerns, leading to higher guest satisfaction and increased customer loyalty. Personalized services and prompt issue resolution can enhance guest retention.
#
# Lowering cancellation rates can provide revenue stability for the City Hotel. Fewer cancellations mean more guaranteed bookings, optimizing room inventory, minimizing revenue losses, and improving revenue predictability.
#
# **Negative Growth Insights:**
#
# The higher cancellation rate in the City Hotel could result in negative growth if not properly managed. Potential negative impacts include revenue loss, operational challenges, and damage to the hotel's reputation. Addressing this issue promptly is crucial to maintain positive growth and success.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Calculate the percentage of each meal type in the dataset
meal_counts = df['meal'].value_counts(normalize=True) * 100

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(meal_counts, labels=meal_counts.index, autopct='%1.1f%%',colors=['lightgreen', 'blue', 'lightcoral', 'yellow', 'pink'])
plt.title('Distribution of Bookings by Meal Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is an ideal choice for visualizing the distribution of bookings across different meal types. It provides a quick and intuitive way to compare the popularity of each meal type at a glance. Each slice of the pie represents a specific meal type, and its size corresponds to the percentage it occupies in the dataset. The labels on the slices make it easy to identify and comprehend each category

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The data analysis reveals that the "Bed and Breakfast" (BB) meal plan is the most preferred choice among guests, constituting around 77.4% of all bookings. Following closely is the "Half Board" (HB) option, selected by approximately 12.1% of guests. The "Self Catering" (SC) meal plan has a smaller but notable share, accounting for approximately 8.8% of bookings.
#
# There is a small percentage, around 1%, of bookings with "Undefined" meal types, which could be due to missing or unspecified meal information.
#
# On the other hand, the "Full Board" (FB) meal plan has the lowest adoption rate, making up only 0.7% of the total bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Knowing that the majority of guests prefer the "Bed and Breakfast" meal plan allows hotels to focus on improving breakfast options, leading to happier guests and increased loyalty.
#
# By understanding the popularity of different meal plans, hotels can manage their inventory more efficiently, reducing waste and operational expenses.
#
# Hotels can use this information to create targeted marketing campaigns for specific meal plans, attracting more bookings and generating higher revenue.
#
# **Negative Growth Insights:**
#
# While the pie chart does not directly reveal negative growth insights, the presence of a small percentage of "Undefined" meal types (around 1%) could lead to operational challenges.
#
# To address this, hotels can encourage guests to specify their meal preferences during booking or check-in, ensuring a smoother meal planning process and avoiding potential inefficiencies.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Distribution of bookings based on the "reserved_room_type"

# Plotting the count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='reserved_room_type', hue='hotel', data=df, palette='pastel')
plt.xlabel('Reserved Room Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Reserved Room Type')
plt.legend(title='Hotel Type', loc='upper right', labels=['Resort Hotel', 'City Hotel'])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I opted for a count plot to visualize the distribution of bookings based on the "reserved_room_type" column because it presents the number of bookings for each room type in a straightforward and easily interpretable manner. This type of chart is ideal for categorical data like room types and provides valuable insights into which room types are more favored by guests at both City Hotels and Resort Hotels. The count plot assists stakeholders in making informed decisions concerning room management, pricing strategies, and promotional activities, leading to positive business outcomes by maximizing revenue and enhancing customer satisfaction. By identifying popular room types, hotels can optimize their offerings to cater to guest preferences and improve overall guest experience..

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most preferred room type among customers, in both City Hotel and Resort Hotel, is 'A', as it has the highest number of bookings.
#
# After 'A', the second most common choice in City Hotel is 'D', whereas in Resort Hotel, it is 'D' followed by 'E'.
#
# Room types 'F', 'G', and 'E' also have a notable number of bookings in both hotels, although they are less popular than 'A' and 'D'.
#
# Some room types are unique to one hotel. For instance, 'H', 'L', and 'C' are exclusive to Resort Hotel, while 'B' is available in both hotels but has very few bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# 1. Optimal Inventory Management: Knowing the preferred room types allows hotels to maintain the right amount of inventory for those rooms, ensuring they can meet the demand and avoid overstocking less popular rooms.
#
# 2. Pricing Strategy: Hotels can set smart pricing by charging slightly more for popular room types, maximizing profits, while offering attractive deals for less popular rooms to boost their demand.
#
# 3. Targeted Marketing and Promotions: Utilizing insights on room popularity, hotels can run targeted marketing campaigns and promotions to attract more guests interested in specific room types.
#
# 4. Efficient Resource Allocation: The data helps hotels allocate resources wisely. They can focus on renovating and maintaining the popular room types to ensure they are appealing to guests.
#
# Negative Growth Concern:
#
# One concern could be underutilization of less popular room types, leading to potential revenue loss. To mitigate this, hotels can offer targeted promotions and incentives to increase the demand for these rooms and avoid resource inefficiency.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Distribution of the number of stays in weekend nights and stays in week nights separately for both city hotels and resort hotels using Box Plots

# Filter data for city hotels and resort hotels
city_hotel_data = df[df['hotel'] == 'City Hotel']
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']

# Create box plot for stays in weekend nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_weekend_nights', data=df, palette='Set1')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Weekend Nights')
plt.title('Distribution of Stays in Weekend Nights for City and Resort Hotels')
plt.show()

# Create box plot for stays in week nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_week_nights', data=df, palette='Set2')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Week Nights')
plt.title('Distribution of Stays in Week Nights for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the box plot to compare the distribution of the number of stays in weekend nights and week nights for both city hotels and resort hotels. It's an effective way to see how the data is spread out and to identify any differences between the two hotel types. By using box plots, we can quickly spot variations in the number of stays between city hotels and resort hotels. It helps us understand if there are any notable differences in booking patterns for the two types of hotels. Additionally, box plots also reveal any unusual or extreme values (outliers) that may require further investigation. Overall, it provides a clear and concise visual representation of the data for easy comparison and analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For both city hotels and resort hotels, most of the bookings during weekends have stays of 2 nights or less. However, in resort hotels, there are more cases of longer weekend stays, with some reservations extending to more than 17 nights. This indicates that resort hotels might attract customers looking for extended weekend getaways or special events.
#
# When it comes to weeknights, the majority of bookings in both types of hotels have stays of 5 nights or less. The median stay duration for weeknights is slightly lower in city hotels compared to resort hotels. Resort hotels, on the other hand, have more outliers with stays of up to 50 nights, suggesting that they attract guests who stay longer during weekdays.
#
# These insights present opportunities for targeted marketing and promotions. Resort hotels can focus on attracting guests seeking extended weekend stays, while both types of hotels can tailor their strategies to cater to guests who require longer weekday stays, such as business travelers or conference attendees.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the box plot can have a positive impact on the hotel's business strategy and marketing efforts. By understanding the booking patterns and guest preferences, the hotel management and marketing teams can design targeted campaigns to attract more guests seeking longer weekend stays in resort hotels. This could lead to increased revenue and higher occupancy rates during weekends. Similarly, tailoring promotions and services for guests looking for extended weekday stays can attract more business travelers and long-term guests, positively affecting revenue and customer loyalty.
#
# However, it's essential to be cautious about the presence of outliers in the data, representing exceptionally long stays in both weekend and weekday bookings. These outliers could indicate potential booking errors or data issues, which might negatively impact customer satisfaction if not addressed promptly. Ensuring data accuracy is crucial to maintaining a positive guest experience and avoiding any negative consequences from incorrect bookings.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Top 10 countries with the Most Guests

# Grouping data by country and calculating total guests from each country
guests_by_country = df.groupby('country')['total_guests'].sum().reset_index()

# Sorting data in descending order of total guests
guests_by_country = guests_by_country.sort_values(by='total_guests', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='total_guests', data=guests_by_country.head(10))
plt.xlabel('Country')
plt.ylabel('Total Guests')
plt.title('Top 10 Countries with the Most Guests')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart to display the number of guests from each country because it provides a quick and clear comparison of guest counts across different countries. With this chart, it is easy to spot which countries have the highest number of guests as the length of the bars directly reflects the guest count. By showing only the top 10 countries, we can focus on the most important contributors to the total number of guests, making the chart more informative and easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Portugal (PRT) stands out as the most popular tourist destination, attracting over 80,000 bookings, indicating its high appeal to guests.
#
# The United Kingdom (GBR) and France (FRA) follow closely with around 20,000+ bookings each, making them significant contributors to the overall number of guests.
#
# Spain (ESP) ranks lower with below 20,000 bookings, suggesting it attracts fewer guests compared to Portugal, the UK, and France.
#
# Germany (DEU) has even fewer bookings than Spain, indicating a lower demand for accommodations from German guests.
#
# Italy (ITA) has fewer bookings than Germany, suggesting it may not be as favored among hotel guests.
#
# Ireland (IRL) records even fewer bookings than Italy, indicating lower demand from Irish guests.
#
# Belgium (BEL), Brazil (BRA), and the USA have the lowest number of bookings among the top 10 countries, pointing to relatively lower demand from guests in these countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# Since a significant number of guests come from Portugal, the UK, and France, hotels can focus on providing tailored services and special promotions to cater to these markets. By doing so, they can potentially attract even more guests from these regions, leading to positive business growth.
#
# **Insights for Negative Growth:**
# On the other hand, the lower number of guests from countries like Germany, Italy, Ireland, Belgium, Brazil, and the USA indicates a potential challenge in attracting guests from these regions. To address this, hotels may need to explore effective marketing strategies and create customized offerings to entice guests from these countries and boost their bookings and revenue.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Top 10 agents who made the highest number of bookings

# Group data by agent and calculate the number of bookings made by each agent
agent_bookings = df['agent'].value_counts().reset_index()
agent_bookings.columns = ['agent', 'num_bookings']

# Sort agents by the number of bookings in descending order
agent_bookings = agent_bookings.sort_values(by='num_bookings', ascending=False)

# Select the top 10 agents with the highest number of bookings
top_10_agents = agent_bookings.head(10)

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='agent', y='num_bookings', data=top_10_agents, palette='viridis')
plt.xlabel('Agent')
plt.ylabel('Number of Bookings')
plt.title('Top 10 Agents with Highest Number of Bookings')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I decided to use a bar chart to show the top 10 agents with the most bookings because it provides a clear and straightforward way to compare different agents based on their booking counts. The chart allows us to quickly see which agents have the highest booking activity and easily compare their performance. The length of the bars directly represents the number of bookings for each agent, making it simple to identify the top performers at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I have analyzed the data and identified the top 10 agents in the hotel industry who have made the highest number of bookings. Among them, Agent ID 9 stands out as the best performer, with an impressive record of over 25,000 bookings. This agent plays a significant role in driving the hotel's business.
#
# Agents with IDs 240 and 0 also demonstrate high performance, securing bookings above 10,000, which brings in a substantial number of customers to the hotel.
#
# On the other hand, agents with IDs 1, 7, 8, 14, 28, 241, and 250 have performed well but have relatively lower booking counts, with figures ranging below 5,000. Despite this, they still contribute positively to the hotel's bookings.
#
# In summary, the top 10 agents exhibit varying levels of success, with Agent ID 9 leading the pack, followed by agents with bookings above 10,000, and the rest having relatively lower booking counts but making valuable contributions to the hotel's business.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The information from this chart can greatly benefit the business. By recognizing the top-performing agents (ID 9, 240, and 0), the hotel management can concentrate on enhancing their collaboration and offering them improved incentives and assistance. Building strong relationships with these leading agents can lead to higher bookings and increased revenue for the hotel.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Selecting numerical columns for correlation analysis
numerical_columns = df.select_dtypes(include=[np.number])

# Calculating the correlation matrix
correlation_matrix = numerical_columns.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the correlation heatmap chart because it visually shows how numerical variables in the dataset are related to each other. It's an effective way to display the correlation matrix, which reveals the strength and direction of the relationships between different variables.
#
# Using the correlation heatmap is especially helpful in Exploratory Data Analysis (EDA) as it provides a quick overview of the connections between features. By looking at the heatmap, we can spot patterns and dependencies among the variables, leading to better-informed decisions during data analysis and modeling.
#
# In essence, the correlation heatmap is a powerful tool to understand the internal relationships within the dataset and to identify important features that influence various aspects of the hotel booking analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The data analysis reveals some interesting findings about hotel bookings:
#
# 1. Longer lead times are associated with a higher likelihood of cancellations. This means that when customers book well in advance, there's a higher chance they might end up canceling their reservations.
#
# 2. There is a significant number of bookings with longer stays (staying for multiple nights). This suggests that many guests plan extended stays at the hotels.
#
# 3. Bookings mostly consist of adults as guests compared to other types of guests (e.g., children or babies). Adult guests form the majority of the bookings.
#
# 4. Guests who make more special requests tend to be less likely to cancel their bookings. This indicates that fulfilling these requests might contribute to higher guest satisfaction and booking retention.
#
# 5. There is a slight increase in lead times for bookings over the years. This suggests that, on average, customers are making their bookings a bit earlier than before.
#
# These insights provide valuable information about the relationships between different factors in hotel bookings. They can serve as a foundation for further analysis and decision-making in the exploratory data analysis (EDA) project.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
data_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'total_guests', 'adr', 'total_of_special_requests']

# Create the pair plot
sns.pairplot(df[data_columns])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the Pair Plot chart because it helps visualize the connections between multiple variables in the dataset. It's ideal when dealing with a small number of numerical variables, as it quickly shows how these variables are distributed and if there are any noticeable patterns or correlations.
# The Pair Plot is a valuable tool for gaining a comprehensive understanding of the relationships between numerical variables. It allows us to identify patterns, correlations, and potential issues, which can guide further analysis and decision-making in the hotel booking analysis project.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. For the majority of customers, the time between booking and arrival (lead time) is below 300, especially for those who stay for multiple nights during the week.
#
# 2. Across all segments, the average daily rate (ADR) is below 1000, indicating that the hotel prices are generally reasonable.
#
# 3. The total number of guests in each booking group (including adults, children, and babies) is less than 10 on average, suggesting that most bookings are for relatively small groups or individuals.
#
# 4. The number of guests staying during weekdays (week nights) is higher compared to the number of guests staying during weekends (weekend nights). This implies that the hotel experiences more business travelers or long-term guests during the weekdays.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Here are some suggestions for the client based on the insights from the analysis:**
#
# 1. Focus on promoting City Hotel: Since City Hotel has more bookings and higher revenue, invest more in marketing and promotions to attract even more guests. Create targeted campaigns to highlight the unique features of City Hotel.
#
# 2. Optimize revenue for City Hotel: Implement dynamic pricing strategies and attractive packages to maximize revenue during peak seasons and events.
#
# 3. Strengthen partnerships with Online Travel Agencies: Since Online TA segment brings a significant number of bookings, collaborate more with these agencies to increase visibility and bookings.
#
# 4. Improve customer experience: Understand guest preferences and reasons for cancellations to enhance overall customer experience. Offer personalized experiences and rewards for direct bookings.
#
# 5. Highlight Resort Hotel's unique offerings: Promote the leisure amenities and scenic locations of Resort Hotel to attract vacationers seeking relaxation.
#
# 6. Strategic room allocation: Focus on popular room types and promote them to optimize bookings and revenue.
#
# 7. Manage lead time and cancellations: Encourage early bookings with special offers and incentives to reduce cancellations.
#
# 8. Customize meal plans: Offer meal plans based on guest preferences, and create attractive meal packages to increase guest satisfaction.
#
# 9. Segment the market: Tailor marketing campaigns for different customer groups to increase bookings from various segments.
#
# 10. Plan promotions during peak months: Focus on marketing and promotional activities during popular vacation seasons to attract more guests.
#
# 11. Strengthen relationships with top agents: Engage in long-term partnerships and offer incentives to top-performing agents.
#
# 12. Enhance direct bookings: Provide competitive rates, special offers, and a seamless booking experience on the website to increase direct bookings.
#
# 13. Implement customer loyalty programs: Encourage repeat bookings and reduce cancellations by introducing loyalty rewards and benefits.
#
# 14. Understand guest demands: Customize offerings and services based on guest preferences and special requests.
#
# 15. Optimize stay duration: Create promotions and packages for guests seeking extended stays or weekend getaways.
#
# **By following these strategies, the client can improve guest satisfaction, attract more bookings, and achieve their business goals. Continuous monitoring of guest preferences and market trends will help them stay competitive in the hotel industry.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **The Hotel Booking Analysis project aimed to study data from City Hotels and Resort Hotels to find useful information. Here are the main findings:**
#
# 1. City Hotels are more popular and get more bookings and revenue than Resort Hotels.
#
# 2. The number of guests fluctuates throughout the year, with August having the most bookings and January the least. April, May, and June are also busy months.
#
# 3. Many guests prefer the "Bed and Breakfast" meal plan and Room Type 'A'.
#
# 4. City Hotel has a higher cancellation rate compared to Resort Hotel. Understanding why guests cancel can help improve the booking process.
#
# 5. Longer lead times might lead to more cancellations. Both hotels make a good amount of revenue, with City Hotel slightly higher.
#
# 6. Travel agencies are the primary booking channel for both hotels, but Resort Hotel gets more revenue from direct bookings.
#
# **Based on these insights, some recommendations are:**
#
# 1. Invest in targeted marketing to promote City Hotel's popularity and attract more guests. Focus on promoting Resort Hotel's unique amenities and locations.
#
# 2. Improve customer experience and address cancellation reasons to enhance guest satisfaction.
#
# 3. Strengthen partnerships with top-performing agents and online travel agencies.
#
# 4. Create promotions during peak months to attract more guests and increase revenue.
#
# 5. Offer special deals for guests who book in advance to reduce cancellations.
#
# 6. Enhance direct booking channels to increase profit margins.
#
# 7. Implement customer loyalty programs to encourage repeat bookings.
#
# 8. Tailor marketing efforts for different customer segments.
#
# **By following these recommendations, hotels can boost their business, improve guest satisfaction, and stay competitive in the industr**y.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
